# %%
dic = { 'a': 1, 'b': 3, 'c': 2 }

dic[ 'a' ]
# Out:
# 1

# %%
dic[ 1 ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dic[ 1 ]
#
# KeyError: 1
