# %%
import CalculatedFieldSubroutines as cfs
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd
import matplotlib.pyplot as plt

#

import numpy as np

import random

#

import cartopy.crs as ccrs

from cartopy.io.img_tiles import OSM, GoogleTiles, StadiaMapsTiles, MapQuestOSM

from pandasgui import show

#

import warnings

#

from sklearn import tree

#

from itertools import permutations

# %%
gmIDs = cfs.list_whitelisted_gmIDs()

topics = cfs.list_topics()

# %%
seconds = 5
sec_df = cfs.retrieve_gmID_preprocessed_moving_data_v2(gmID = gmIDs[ 0 ], moving_window = seconds)

# %%
test_df1 = cfs.retrieve_gmID_preprocessed_moving_data_v2( gmID = gmIDs[ 0 ], moving_window = 0 )

# %%
test_df2 = cfs.retrieve_gmID_preprocessed_moving_data_v2( gmID = gmIDs[ 0 ], moving_window = 5 )

# %%
def solColumns(df):
    df['solChange'] = 0
    df['Changesol'] = None
    for index in range(1, len(df)):
        currentType = df.loc[index, 'solType']
        pastType = df.loc[index - 1 , 'solType']
        if currentType == pastType:
            df.loc[index, 'solChange'] = 0 
        else:
            df.loc[index, 'solChange'] = 1 
        df.loc[index, 'Changesol'] = f'{pastType}->{currentType}'
    firstType = df.loc[0,'solType']
    df.loc[0,'Changesol'] = f'{firstType}->{firstType}'

# %%
solColumns(test_df1)

# %%
test_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40864 entries, 0 to 40863
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ind                          40864 non-null  int64
#  1   groupMetadataID              40864 non-null  object
#  2   time                         40864 non-null  int64
#  3   NormalizedTime               40864 non-null  float64
#  4   BinaryDrivingMode            40864 non-null  int64
#  5   BinaryDisengagement          40864 non-null  int64
#  6   BinaryDisengagementExpanded  40864 non-null  int64
#  7   DisengagementID              40864 non-null  object
#  8   DisengagementExpandedID      40864 non-null  object
#  9   latitude                     40864 non-null  float64
#  10  longitude                    40864 non-null  float64
#  11  ProgressAlongRoute           40864 non-null  float64
#  12  solStatus                    40864 non-null  object
# ...

# %%
test_df1['solChange'].value_counts()
# Out:
# solChange
# 0    40845
# 1       19
# Name: count, dtype: int64

# %%
test_df1['Changesol'].value_counts()
# Out:
# Changesol
# NARROW_INT->NARROW_INT        36405
# PSRDIFF->PSRDIFF               3689
# NARROW_FLOAT->NARROW_FLOAT      693
# SINGLE->SINGLE                   58
# NARROW_FLOAT->PSRDIFF             4
# PSRDIFF->NARROW_FLOAT             3
# NARROW_INT->PSRDIFF               3
# PSRDIFF->NARROW_INT               3
# PSRDIFF->SINGLE                   2
# NARROW_FLOAT->NARROW_INT          1
# SINGLE->NARROW_FLOAT              1
# NARROW_INT->NARROW_FLOAT          1
# SINGLE->PSRDIFF                   1
# Name: count, dtype: int64

# %%
test_df1.head()
# Out:
#    Ind                       groupMetadataID                 time  \
# 0    0  aa86a660-dc05-11ee-a158-97f8443fd730  1693507928636583162
# 1    1  aa86a660-dc05-11ee-a158-97f8443fd730  1693507928663151054
# 2    2  aa86a660-dc05-11ee-a158-97f8443fd730  1693507928699243780
# 3    3  aa86a660-dc05-11ee-a158-97f8443fd730  1693507928736974228
# 4    4  aa86a660-dc05-11ee-a158-97f8443fd730  1693507928764847784
#
#    NormalizedTime  BinaryDrivingMode  BinaryDisengagement  \
# 0        0.000000                  0                    0
# 1        0.000014                  0                    0
# 2        0.000034                  0                    0
# 3        0.000055                  0                    0
# 4        0.000070                  0                    0
#
#    BinaryDisengagementExpanded DisengagementID DisengagementExpandedID  \
# 0                            0             NAD                     NAD
# 1                            0             NAD                     NAD
# ...
