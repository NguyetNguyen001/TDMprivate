# %%
import CalculatedFieldSubroutines as cfs

# %%
gmIDs = cfs.list_whitelisted_gmIDs()

# %%
topics = cfs.list_topics()

print( topics )
# Out:
# ['/apollo/sensor/gnss/best/pose', '/apollo/drive/event', '/apollo/canbus/chassis', '/apollo/perception/traffic/light']

# %%
df = cfs.retrieve_gmID_topic( gmIDs[ 4 ], '/apollo/canbus/chassis' )

# %%
red_dfs = []

for gmID in gmIDs:

    if ( cfs.give_route( gmID ) != 'Red' ):

        continue

    df = cfs.retrieve_gmID_topic( gmID, '/apollo/canbus/chassis' )

    cfs.BinaryDrivingMode( df )

    red_dfs.append( df )

# %%
red_dfs[ 0 ]
# Out:
#        brakePercentage                       groupMetadataID  \
# 0                  0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 1                  0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 2                  0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 3                  0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 4                  0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# ...                ...                                   ...
# 28704              0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 28705              0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 28706              0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 28707              0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
# 28708              0.0  3151e9e2-eff3-11ee-b966-fb353e7798cd
#
#                drivingMode  speedMps                 time  throttlePercentage  \
# 0          COMPLETE_MANUAL      2.57  1696344951051144534                 0.0
# 1          COMPLETE_MANUAL      2.58  1696344951089635794                 0.0
# 2          COMPLETE_MANUAL      2.61  1696344951116835903                 0.0
# 3          COMPLETE_MANUAL      2.62  1696344951151246536                 0.0
# 4          COMPLETE_MANUAL      2.63  1696344951184689475                 0.0
# ...                    ...       ...                  ...                 ...
# 28704  COMPLETE_AUTO_DRIVE     18.80  1696345898725712710                15.0
# 28705  COMPLETE_AUTO_DRIVE     18.80  1696345898748429353                15.6
# 28706  COMPLETE_AUTO_DRIVE     18.81  1696345898802495521                15.7
# 28707  COMPLETE_AUTO_DRIVE     18.81  1696345898821449123                15.8
# 28708  COMPLETE_AUTO_DRIVE     18.81  1696345898843862972                16.0
#
#        steeringPercentage signal.turnSignal  BinaryDrivingMode
# 0               -75.73947         TURN_NONE                  0
# 1               -75.73947         TURN_NONE                  0
# 2               -75.73947         TURN_NONE                  0
# 3               -75.73947         TURN_NONE                  0
# 4               -75.73947         TURN_NONE                  0
# ...                   ...               ...                ...
# 28704             1.51812         TURN_NONE                  1
# 28705             1.51812         TURN_NONE                  1
# 28706             1.51812         TURN_NONE                  1
# 28707             1.51812         TURN_NONE                  1
# 28708             1.51812         TURN_NONE                  1
#
# [28709 rows x 9 columns]

# %%
green_dfs = []

for gmID in gmIDs:

    if ( cfs.give_route( gmID ) != 'green' ):

        continue

    df = cfs.retrieve_gmID_topic( gmID, '/apollo/canbus/chassis' )

    cfs.BinaryDrivingMode( df )

    green_dfs.append( df )

# %%
green_dfs[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 green_dfs[0]
#
# IndexError: list index out of range
