# %%
import CalculatedFieldSubroutines as cfs
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd
import matplotlib.pyplot as plt

#

import numpy as np

import random

#

import cartopy.crs as ccrs

from cartopy.io.img_tiles import OSM, GoogleTiles, StadiaMapsTiles, MapQuestOSM

from pandasgui import show

#

import warnings

#

from sklearn import tree

#

from itertools import permutations

# %%
topics = cfs.list_topics()

print( topics )
# Out:
# ['/apollo/sensor/gnss/best/pose', '/apollo/drive/event', '/apollo/canbus/chassis', '/apollo/perception/traffic/light']

# %%
gmIDs = cfs.list_whitelisted_gmIDs()

# %%
df = cfs.retrieve_gmID_topic( gmIDs[ 4 ], '/apollo/canbus/chassis' )

# %%
red_dfs = []

for gmID in gmIDs:

    if ( cfs.give_route( gmID ) != 'Red' ):

        continue

    df = cfs.retrieve_gmID_topic( gmID, '/apollo/canbus/chassis' )

    cfs.BinaryDrivingMode( df )

    cfs.TernaryDrivingModeTransition( df )

    red_dfs.append( df )

# %%
red_dfs[ 0 ]
# Out:
#        brakePercentage                       groupMetadataID     drivingMode  \
# 0                 35.2  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 1                 35.2  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 2                 35.2  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 3                 35.2  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 4                 35.2  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# ...                ...                                   ...             ...
# 65111              0.0  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 65112              0.0  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 65113              0.0  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 65114              0.0  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
# 65115              0.0  85b6e70e-ef7a-11ee-b966-fb353e7798cd  EMERGENCY_MODE
#
#        speedMps                 time  throttlePercentage  steeringPercentage  \
# 0          0.00  1692380592431452989                 0.0          100.068560
# 1          0.00  1692380592452823478                 0.0          100.068560
# 2          0.00  1692380592482829657                 0.0          100.068560
# 3          0.00  1692380592523978140                 0.0          100.068560
# 4          0.00  1692380592559489174                 0.0          100.068560
# ...         ...                  ...                 ...                 ...
# 65111      0.53  1692382741681874759                13.3          105.004900
# 65112      0.55  1692382741707241001                13.3          105.024480
# 65113      0.58  1692382741739341010                13.3          105.024480
# 65114      0.61  1692382741790751613                13.3          105.044075
# 65115      0.61  1692382741806659068                13.3          105.044075
#
#       signal.turnSignal  BinaryDrivingMode  TernaryDrivingModeTransition
# 0             TURN_NONE                  0                             0
# 1             TURN_NONE                  0                             0
# 2             TURN_NONE                  0                             0
# 3             TURN_NONE                  0                             0
# 4             TURN_NONE                  0                             0
# ...                 ...                ...                           ...
# 65111         TURN_NONE                  0                             0
# 65112         TURN_NONE                  0                             0
# 65113         TURN_NONE                  0                             0
# 65114         TURN_NONE                  0                             0
# 65115         TURN_NONE                  0                             0
#
# [65116 rows x 10 columns]

# %%
green_dfs = []

for gmID in gmIDs:

    if ( cfs.give_route( gmID ) != 'Green' ):

        continue

    df = cfs.retrieve_gmID_topic( gmID, '/apollo/canbus/chassis' )

    cfs.BinaryDrivingMode( df )

    cfs.TernaryDrivingModeTransition( df )

    green_dfs.append( df )

# %%
green_dfs[0]
# Out:
#        brakePercentage                       groupMetadataID     drivingMode  \
# 0                 42.6  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 1                 42.6  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 2                 42.6  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 3                 42.6  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 4                 42.6  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# ...                ...                                   ...             ...
# 24166              0.0  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 24167              0.0  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 24168              0.0  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 24169              0.0  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
# 24170              0.0  848e44a6-f134-11ee-ba6d-fb353e7798cd  EMERGENCY_MODE
#
#        speedMps                 time  throttlePercentage  steeringPercentage  \
# 0          0.00  1705947367023734441                 0.0           -1.224290
# 1          0.00  1705947367062376703                 0.0           -1.224290
# 2          0.00  1705947367090596248                 0.0           -1.224290
# 3          0.00  1705947367124406305                 0.0           -1.224290
# 4          0.00  1705947367155491616                 0.0           -1.224290
# ...         ...                  ...                 ...                 ...
# 24166     10.31  1705948164733684388                 0.0           13.839374
# 24167     10.30  1705948164765853969                 0.0           13.428012
# 24168     10.29  1705948164799907366                 0.0           12.869736
# 24169     10.28  1705948164831825181                 0.0           12.389814
# 24170     10.28  1705948164866822102                 0.0           11.860921
#
#       signal.turnSignal  BinaryDrivingMode  TernaryDrivingModeTransition
# 0             TURN_NONE                  0                             0
# 1             TURN_NONE                  0                             0
# 2             TURN_NONE                  0                             0
# 3             TURN_NONE                  0                             0
# 4             TURN_NONE                  0                             0
# ...                 ...                ...                           ...
# 24166         TURN_NONE                  0                             0
# 24167         TURN_NONE                  0                             0
# 24168         TURN_NONE                  0                             0
# 24169         TURN_NONE                  0                             0
# 24170         TURN_NONE                  0                             0
#
# [24171 rows x 10 columns]

# %%
blue_dfs = []

for gmID in gmIDs:

    if ( cfs.give_route( gmID ) != 'Blue' ):

        continue

    df = cfs.retrieve_gmID_topic( gmID, '/apollo/canbus/chassis' )

    cfs.BinaryDrivingMode( df )
    
    cfs.TernaryDrivingModeTransition( df )

    blue_dfs.append( df )

# %%
blue_dfs[0]
# Out:
#        brakePercentage                       groupMetadataID      drivingMode  \
# 0                  0.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 1                  0.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 2                  0.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 3                  0.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 4                  0.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# ...                ...                                   ...              ...
# 97264             30.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 97265             30.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 97266             30.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 97267             30.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
# 97268             30.0  feaf2ba8-d28d-11ee-b437-336917683bb8  COMPLETE_MANUAL
#
#        speedMps                 time  throttlePercentage  steeringPercentage  \
# 0      5.904951  1698251666488335112                 8.8           35.573590
# 1      5.904951  1698251666508212969                 8.8           35.573590
# 2      5.904951  1698251666528289293                 8.8           35.573590
# 3      5.937503  1698251666548249002                 8.8           35.036280
# 4      5.937503  1698251666571191351                 8.8           35.036280
# ...         ...                  ...                 ...                 ...
# 97264  0.000000  1698253614468233317                 0.0            0.277919
# 97265  0.000000  1698253614488224549                 0.0            0.277919
# 97266  0.000000  1698253614511209652                 0.0            0.277919
# 97267  0.000000  1698253614526275600                 0.0            0.277919
# 97268  0.000000  1698253614548311572                 0.0            0.277919
#
#       signal.turnSignal  BinaryDrivingMode  TernaryDrivingModeTransition
# 0             TURN_NONE                  0                             0
# 1             TURN_NONE                  0                             0
# 2             TURN_NONE                  0                             0
# 3             TURN_NONE                  0                             0
# 4             TURN_NONE                  0                             0
# ...                 ...                ...                           ...
# 97264         TURN_NONE                  0                             0
# 97265         TURN_NONE                  0                             0
# 97266         TURN_NONE                  0                             0
# 97267         TURN_NONE                  0                             0
# 97268         TURN_NONE                  0                             0
#
# [97269 rows x 10 columns]

# %%
print(isinstance(red_dfs[0],pd.DataFrame))
print(isinstance(green_dfs[0],pd.DataFrame))
print(isinstance(blue_dfs[0],pd.DataFrame))
# Out:
# True
# True
# True

# %%
X_name = ['brakePercentage','speedMps','throttlePercentage','steeringPercentage']
y_name = 'BinaryDrivingMode'           
training_red_dfs, testing_red_dfs = cfs.random_list_split(red_df)

training_red_df = pd.concat( training_red_dfs )

testing_red_df = pd.concat( testing_red_dfs )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 X_name = ['brakePercentage','speedMps','throttlePercentage','steeringPercentage']
#       2 y_name = 'BinaryDrivingMode'
# ----> 3 training_red_dfs, testing_red_dfs = cfs.random_list_split(red_df)
#       5 training_red_df = pd.concat( training_red_dfs )
#       7 testing_red_df = pd.concat( testing_red_dfs )
#
# AttributeError: module 'CalculatedFieldSubroutines' has no attribute 'random_list_split'
