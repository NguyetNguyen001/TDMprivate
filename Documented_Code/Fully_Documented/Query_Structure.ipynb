# %% [markdown]
# ### Query Structure Tutorial
#
# This notebook will give you an introduction into how to query the data from DriveOhio's DynamoDB database into your Amazon WorkSpace.
#
# Assuming the one reading this is part of a team picking up on our work, there is a notebook ('Mass_Data_Query_v2.ipynb') to query the data exactly how we did it; however, if you ever want to use more data (such as new independent variables) that we decided not to pull, you will need to learn how to work with DynamoDB in a Python environment.
#
# -Ryan

# %% [markdown]
# As an important sidenote, when you query data, be deliberate in how you query. The reason behind this is twofold:
#
# 1. There is a lot of data in the DynamoDB database. Two queries that produce the same output may have runtimes differing in days, so try to write a more efficient query over a less efficient one.
# 2. Downloading from the DynamoDB database costs DriveOhio money, albeit a paltry amount, but small amounts can add up. Do not leave any infinite while loops running when pulling data or repeatly pull if you do not need too. I would recommend setting up a query to get all the data you need and store it in a safe place on your Amazon WorkSpace, not to be modified. This way, you can make copies of it internal to your Amazon WorkSpace to modify as much as you want, knowing there is an unmodified copy as a back up.

# %% [markdown]
# ##### References
#
# 1. General DynamoDB and Boto3 Info: https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/programming-with-python.html
# 2. DynamoDB Python Guide: https://boto3.amazonaws.com/v1/documentation/api/latest/guide/dynamodb.html
# 3. Scan vs. Query: https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/bp-query-scan.html
# 4. Resource Scan Documentation: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/dynamodb/table/scan.html
# 5. Resource Query Documentation: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/dynamodb/table/query.html
# 6. Key() and Attr() Documentation: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/customizations/dynamodb.html#ref-dynamodb-conditions

# %%
# Imports the Amazon Web Services (AWS) Software Development Kit (SDK) for Python (Reference 1 - About Boto section)

import boto3 

# Imports the 'Key' and 'Attr' classes, which are used to set conditions when querying or scanning data from a table in DynamoDB

# (Reference 2 - Querying and Scanning section)

from boto3.dynamodb.conditions import Key, Attr

# Imports Pandas, an extremely popular data manipulation and analyis library in Python

import pandas as pd

# %%
# Initializes a higher-level interface called 'resource' that is able to access most of the tools in DynamoDB
# (There is a lower-level interface called 'client' that can access more of DynamoDB's tools compared to 'resource', 
# but it is more complicated, so I didn't learn how to use it.)

# (Reference 1 - Understanding the client and resource abstraction layers)

dynamodb = boto3.resource( 'dynamodb' )

# %%
# Accesses the 'ads_passenger_processed' table from DriveOhio in the DynamoDB database
# This is one of the two tables available to us (those being 'ads_passenger_processed' and 'ads_passenger_processed_metadata')

adspp_table = dynamodb.Table( 'ads_passenger_processed' )

# %%
# Before we do a query on the table 'adspp_table', let us look at a small subset of the table to get a feel for its structure

# This code returns the first 1 MB of data in the table

scan_output = adspp_table.scan()

# The 'scan' method is similar to the 'query' method we will use later, but is usually much slower when requesting data 
# from a table, especially if the table is large. The reason behind this, in short, is that the 'scan' method iterates through
# the entirity of a table, then picks out the rows you requested using the filters afterwards. The 'query' method on the other 
# hand iterates through a primary key or index key in the table that matches a certain value, then applies any more filters
# you specified afterwards. Depending on what primary or index key condition you choose, the 'query' method may only have
# to iterate over a small subset of the table, potentially making it a lot faster than 'scan'. For small tables, 'scan' is
# still fine to use and may be more versatile and simple, hence why I used it above.

# (Reference 3)

# One last comment, both the 'scan' and 'query' methods return a maximum of 1 MB of data from one usage. For tables larger than
# 1 MB, one has perform multiple scans or queries, each starting where the last scan or query left off, in order to access all of
# the table. Additionally, one needs to remember to save the data pulled out of the table after each query in another object, such
# as a Pandas dataframe, else it will be lost.

# (References 4 and 5)

# %%
# The output of the 'scan' method is a dictionary containing items which are useful to understand (the output is
# extremely similar to a 'query' output)

# This code simply prints the keys of the scan output dictionary

print( dict.keys( scan_output ) )
# Out:
# dict_keys(['Items', 'Count', 'ScannedCount', 'LastEvaluatedKey', 'ResponseMetadata'])

# %%
# The 'Items' key is the most important key, as this is where the rows we requested from the table are contained. These
# rows are stored in a list. Each row in this list is a dictionary, with its keys being the column names in
# that row and the values being the values associated with those column names in that row.

# (References 4 and 5 - Response Structure)

# Let's take a look at the first row of the table:

# The following code displays each column name and the value for that column in the first row of the table. It looks a bit complicated
# just because I wanted to display it nicely. If one wants the raw dictionary, simply do print( scan_output[ 'Items' ][ 0 ] ),
# which I'll do in the next cell

key_lens = [ len( key ) for key in scan_output[ 'Items' ][ 0 ].keys() ]
max_key_len = max( key_lens )

print('Attribute' + ' '*12 + 'Value \n')
for key, val in scan_output[ 'Items' ][ 0 ].items():

    space = max_key_len - len( key )

    print( str( key ) + ' ' * ( space + 3 ) + str( val ) )
# Out:
# Attribute            Value
#
# yawRate              0
# drivingMode          COMPLETE_AUTO_DRIVE
# topic                /apollo/canbus/chassis
# msgsize              133
# time                 1701972580600806943
# gearLocation         GEAR_DRIVE
# metadataID           e3362dcd-f0e0-11ee-ba1e-fb353e7798cd
# throttlePercentage   11.6
# steeringPercentage   0.74436826
# brakePercentage      0
# engageAdvice         {'advice': 'READY_TO_ENGAGE'}
# groupMetadataID      1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd
# errorCode            NO_ERROR
# signal               {'turnSignal': 'TURN_NONE'}
# steeringRate         0
# header               {'moduleName': 'canbus', 'sequenceNum': Decimal('11358'), 'timestampSec': Decimal('1701972580.6002243')}
# speedMps             19.71
# engineStarted        True
# _id                  ed569d6e-f0e0-11ee-ba1e-fb353e7798cd
# fuelRangeM           0
# msg_type
# wheelSpeed           {'isWheelSpdRrValid': True, 'wheelSpdRr': Decimal('57.4'), 'isWheelSpdRlValid': True, 'wheelSpdFr': Decimal('57.59'), 'isWheelSpdFrValid': True, 'wheelSpdRl': Decimal('57.47'), 'wheelSpdFl': Decimal('57.43'), 'isWheelSpdFlValid': True}

# %%
# What the first row actually looks like as a dictionary

print( scan_output[ 'Items' ][ 0 ] )
# Out:
# {'yawRate': Decimal('0'), 'drivingMode': 'COMPLETE_AUTO_DRIVE', 'topic': '/apollo/canbus/chassis', 'msgsize': Decimal('133'), 'time': Decimal('1701972580600806943'), 'gearLocation': 'GEAR_DRIVE', 'metadataID': 'e3362dcd-f0e0-11ee-ba1e-fb353e7798cd', 'throttlePercentage': Decimal('11.6'), 'steeringPercentage': Decimal('0.74436826'), 'brakePercentage': Decimal('0'), 'engageAdvice': {'advice': 'READY_TO_ENGAGE'}, 'groupMetadataID': '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd', 'errorCode': 'NO_ERROR', 'signal': {'turnSignal': 'TURN_NONE'}, 'steeringRate': Decimal('0'), 'header': {'moduleName': 'canbus', 'sequenceNum': Decimal('11358'), 'timestampSec': Decimal('1701972580.6002243')}, 'speedMps': Decimal('19.71'), 'engineStarted': True, '_id': 'ed569d6e-f0e0-11ee-ba1e-fb353e7798cd', 'fuelRangeM': Decimal('0'), 'msg_type': '', 'wheelSpeed': {'isWheelSpdRrValid': True, 'wheelSpdRr': Decimal('57.4'), 'isWheelSpdRlValid': True, 'wheelSpdFr': Decimal('57.59'), 'isWheelSpdFrValid': True, 'wheelSpdRl': Decimal('57.47'), 'wheelSpdFl': Decimal('57.43'), 'isWheelSpdFlValid': True}}

# %%
# The 'Count' and 'ScannedCount' keys contain integers representing the number of rows returned before and after applying the 
# filters one specificied in the 'scan' method. It's not too important to pay attention to these, although if the ratio
# between the 'ScannedCount' and 'Count' numbers is particularly small, it indicates the scan was inefficient.

# (References 4 and 5 - Response Structure)

print( 'Count: ', scan_output[ 'Count' ] )
print( 'ScannedCount: ', scan_output[ 'ScannedCount' ] )

# One can see the 'ScannedCount' and 'Count' numbers are the same because we did not set any filters in our scan
# Out:
# Count:  1324
# ScannedCount:  1324

# %%
# The 'LastEvaluatedKey' key is an important one. Because the 'scan' and 'query' methods only return a maximum of 1 MB of 
# data from a table, if a table has more than 1 MB of data, we need a way to do another 'scan' or 'query' starting at the 
# row where the previous one stopped. The 'LastEvaluatedKey' key contains the primary key of the row a 'scan' 
# or 'query' method stopped, and if put as an argument in another 'scan' or 'query' method, will start that 'scan' or
# 'query' at that row.

# If the LastEvaluatedKey' key is absent from a 'scan' or 'query' output, that means the 'scan' or 'query' has reached the
# end of the table

print( scan_output[ 'LastEvaluatedKey' ] )

# ^^^ By looking at the 'LastEvaluatedKey', we can see that the primary key of the 'ads_passenger_processed' table is a 
# combination of the '_id' and 'time' columns. In DynamoDB, '_id' is what would be refered to as the 'partition key' and
# 'time' as the 'sort key'.

# (References 4 and 5 - Response Structure)
# Out:
# {'_id': '628a6707-f1a1-11ee-bac2-fb353e7798cd', 'time': Decimal('1706040720012172773')}

# %%
# I am not entirely sure on what the 'ResponseMetadata' does yet, I think it is related to error handling. For our purposes,
# it does not seem important.

print( scan_output[ 'ResponseMetadata' ] )
# Out:
# {'RequestId': '7N43P7CT58EC9U43V55Q217OTFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Sun, 13 Apr 2025 17:22:17 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '1831761', 'connection': 'keep-alive', 'x-amzn-requestid': '7N43P7CT58EC9U43V55Q217OTFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '399128536'}, 'RetryAttempts': 0}

# %%
# Now that we have looked at what the output of a 'scan' and 'query' contains, let's take a look at the table beyond just the first
# row, just as another step to get a feel for its structure. We'll do this by using Pandas

# This line puts the rows in the 'Items' key into a Pandas dataframe

scan_output_df = pd.DataFrame.from_dict( pd.json_normalize( scan_output[ 'Items' ] ), orient = 'columns' )

# %%
# Now, let's just show it

scan_output_df

# What we can notice is that there are a lot of columns, and a lot of rows have missing data for these 
# columns. The value present in the 'topic' column seems to be associated with which columns
# are filled, so, although '_id' and 'time' might be the primary key, 'topic' might be a good column to index over
# to extract a certain group of columns.
# Out:
#      yawRate          drivingMode                              topic msgsize  \
# 0          0  COMPLETE_AUTO_DRIVE             /apollo/canbus/chassis     133
# 1        NaN                  NaN       /apollo/sensor/gnss/odometry     109
# 2        NaN                  NaN                                /tf     103
# 3        NaN                  NaN    /apollo/localization/msf_status      69
# 4        NaN                  NaN  /apollo/sensor/gnss/corrected_imu     100
# ...      ...                  ...                                ...     ...
# 1319     NaN                  NaN       /apollo/sensor/gnss/raw_data     106
# 1320     NaN                  NaN       /apollo/sensor/gnss/odometry     109
# 1321     NaN                  NaN  /apollo/sensor/gnss/corrected_imu     100
# 1322     NaN                  NaN    /apollo/localization/msf_status      24
# 1323     NaN                  NaN         /apollo/sensor/radar/front   13541
#
#                      time gearLocation                            metadataID  \
# 0     1701972580600806943   GEAR_DRIVE  e3362dcd-f0e0-11ee-ba1e-fb353e7798cd
# 1     1693325927615587598          NaN  4931fe4c-efa0-11ee-b966-fb353e7798cd
# 2     1704824442246497208          NaN  88c81562-f105-11ee-ba41-fb353e7798cd
# 3     1694623978391998055          NaN  644d56b6-c85a-11ee-a7fc-dd032dba19e8
# 4     1695151060395748558          NaN  9376f90f-eff0-11ee-b966-fb353e7798cd
# ...                   ...          ...                                   ...
# 1319  1706556966501546224          NaN  7e61bf76-f1df-11ee-baeb-fb353e7798cd
# 1320  1694625128091941540          NaN  1864856a-c867-11ee-a7fc-dd032dba19e8
# 1321  1708622383997060362          NaN  3060bdff-ed42-11ee-9385-ef789ffde1d3
# 1322  1695838314211955993          NaN  e35fd246-ca98-11ee-909c-e1dc60cf66f9
# 1323  1706040720012172773          NaN  2489b816-f1a1-11ee-bac2-fb353e7798cd
#
#      throttlePercentage steeringPercentage brakePercentage  ...  \
# 0                  11.6         0.74436826               0  ...
# 1                   NaN                NaN             NaN  ...
# 2                   NaN                NaN             NaN  ...
# 3                   NaN                NaN             NaN  ...
# 4                   NaN                NaN             NaN  ...
# ...                 ...                ...             ...  ...
# 1319                NaN                NaN             NaN  ...
# 1320                NaN                NaN             NaN  ...
# 1321                NaN                NaN             NaN  ...
# 1322                NaN                NaN             NaN  ...
# 1323                NaN                NaN             NaN  ...
#
#      modules.Planning modules.Localization modules.Transform modules.Canbus  \
# 0                 NaN                  NaN               NaN            NaN
# 1                 NaN                  NaN               NaN            NaN
# 2                 NaN                  NaN               NaN            NaN
# 3                 NaN                  NaN               NaN            NaN
# 4                 NaN                  NaN               NaN            NaN
# ...               ...                  ...               ...            ...
# 1319              NaN                  NaN               NaN            NaN
# 1320              NaN                  NaN               NaN            NaN
# 1321              NaN                  NaN               NaN            NaN
# 1322              NaN                  NaN               NaN            NaN
# 1323              NaN                  NaN               NaN            NaN
#
#      monitoredComponents.Lidar.status monitoredComponents.ESD-CAN.message  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
# ...                               ...                                 ...
# 1319                              NaN                                 NaN
# 1320                              NaN                                 NaN
# 1321                              NaN                                 NaN
# 1322                              NaN                                 NaN
# 1323                              NaN                                 NaN
#
#      monitoredComponents.ESD-CAN.status monitoredComponents.GPS.message  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 1319                                NaN                             NaN
# 1320                                NaN                             NaN
# 1321                                NaN                             NaN
# 1322                                NaN                             NaN
# 1323                                NaN                             NaN
#
#      monitoredComponents.GPS.status monitoredComponents.Localization.status
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
# ...                             ...                                     ...
# 1319                            NaN                                     NaN
# 1320                            NaN                                     NaN
# 1321                            NaN                                     NaN
# 1322                            NaN                                     NaN
# 1323                            NaN                                     NaN
#
# [1324 rows x 510 columns]

# %%
# Suppose we want to find the values for the 'time' and 'throttlePercentage' columns in rows containing the value
# 1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd for the 'groupMetadataID' column. We can do this using the 'query' method.
# Notice that the 'throttlePercentage' column only has values for rows with the value /apollo/canbus/chassis for
# the 'topic' column, so we should index over where 'topic' is equal to /apollo/canbus/chassis to be efficient.
# We can perform this task without having to iterate over the entire table, which would take a very long time, by
# choosing a good column to index over.

# In order to do this query, we need to define the parameters that will go into it. The query below contains all the
# non-legacy parameters that the 'query' method in DyanmoDB can take. Some are very important, some are not necessary.
# I will describe each one, but in case you run into an error in the future or wants a thourough explanation, I recommend
# looking at Reference 5, as it contains a lot of useful info.

# (Reference 5 - Request Syntax)

query_input = dict(
    
                   IndexName = 'topic-index', # !!! If one wants to index over a column in a table that is NOT the primary key,
                                              # one needs to specify that column here. Typically, one would write this
                                              # parameter as the name of the column one wants to index over + '-index'
                                              # If omitted, the query will index over the primary key. (a string)

                                              # Notice, because we want to index over 'topic' for our current query, it is set to
                                              # 'topic-index'.

                   # Select = # Much of what this parameter does is done implicitly and is not necessary. If one does encounter a
                              # scenario in which it is needed, please refer to the documentation in Reference 5. (a string)
                              # (Essentially this parameter specifies whether all, some, or no attributes are to be outputted)
    
                   Limit = 2000, # This parameter limits the number of rows that can be iterated over to less than or
                                 # equal to what it is set to. Two scenarios in which it will not iterate over the maximum number 
                                 # of rows specified here are as follows: the table does not have that many rows left or the 1 MB limit 
                                 # for the query as been reached. This parameter is not necessary. (an integer)
    
                   # ConsistentRead = # A parameter that determines whether the data in the rows being iterated over and pulled out
                                      # is fully up to date with the latest insertions, updates, or deletions. Not necessary to specify
                                      # unless the table is being modified frequently. (a boolean)
    
                   # ScanIndexForward = # A parameter that determines whether the table is traversed in ascending or 
                                        # descending order in the context of the sort key. Default is true. Likely not 
                                        # necessary to specify. (a boolean)
    
                   # ExclusiveStartKey = # !!! A parameter to specify what row the query should start at. Specifically, this is the 
                                         # primary key of the first row the query will start at. This parameter is extremely 
                                         # important when one wants to query a table larger than 1 MB, as a single query will not iterate
                                         # over all of it. The 'LastEvaluatedKey' of the output of a previous query is usually put here
                                         # to continue where it left off. (a dict)

                                         # If omitted, the query will start at the top or bottom row in the context of the sort key.
    
                   # ReturnConsumedCapacity = # A parameter which adds a metric indicating the amount of data(?) consumed by the query to 
                                              # the output of the query. Not necessary. (a string)

                   ProjectionExpression = '#time, throttlePercentage',

                   # !!! ^^^ A parameter that determines what columns will be retrtieved by the query. If one wants all 
                   # available columns in each row, this parameter should be omitted. Otherwise, one should write
                   # the desired columns in a comma seperated list as a string. Ex. 'attr1, attr2, attr3, attr4'. (a string)

                   # Notice, because we want to find the values of the 'time' and 'throttlePercentage' columns for our current
                   # query, these columns have been listed. However, you might notice that the 'time' column has a # attached
                   # to its front. This is because the word 'time' is actually a reserved word in DynamoDB. If an column is a
                   # a reserved word or has special characters that cause it to be misinterpreted, it needs to be assigned an alias
                   # to be used in expressions using the ExpressionAttributeNames key further below.
    
                   FilterExpression = Attr( 'groupMetadataID' ).eq( '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd' ),

                   # !!! ^^^ A parameter containing conditions columns in each row must satisfy in order for that row to
                   # be in the query output. The conditions are written as Attr() taking the name of an column one would like to
                   # filter, then after the parenthesis, a period and the type of condition the column must satisfy. If one does
                   # not want to add any extra conditions aside from the KeyConditionExpression, this parameter may be omitted.

                   # ^^^ Correction: the columns in the FilterExpression must not include the column being indexed over (in 
                   # this case, 'topic' should not be a column in FilterExpression)

                   # General Form: Attr( column_name ).condition()

                   # There are many conditions one may apply to an Attr( column_name ), such as .eq( value ) [checking if an 
                   # column is equal to a certain value], .ne( value ) [not equal to a value], .between( low_value, high_value )
                   # [between two values], etc. A full list of conditions that can act on Attr() can be found in Reference 6.

                   # In the FilterExpression parameter, multiple conditions may be chained together using the & symbol.
                   # Ex. Attr( column_name1 ).condition1() & Attr( column_name2 ).condition2()

                   # For the current query, the FilterExpression checks if the 'groupMetadataID' column is equal to
                   # '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd'.

                   # Reference 6

                   KeyConditionExpression = Key( 'topic' ).eq( '/apollo/canbus/chassis' ),

                   # !!! ^^^ A parameter containing conditions the column being indexed over in each row must satisfy in
                   # order for that row to be iterated over and potentially sent to the output. The reason that the rows
                   # iterated over are only potentially sent to the output is that they must also pass the filtering in the
                   # FilterExpression before being sent to the output. Essentially, the KeyConditionExpression parameter picks
                   # the rows out of the table satisfying the conditions for the column being indexed over, then, only after
                   # collecting all them, sends them to the FilterExpression, which then sends the filtered rows to the output.

                   # ^^^ If IndexName is omitted, the column(s) being indexed over is the primary key. The primary key
                   # may consist of a partition key, or a partition key and a sort key. In this case, the KeyConditionExpression
                   # must consist of a condition for the partition key or the partition key and the sort key, but not the sort
                   # key alone.

                   # The KeyConditionExpression parameter is a required part of a query. It must consist of a condition for 
                   # the partition key, the partition key and the sort key, or the column being indexed over.

                   # General Form: Key( indexed_column_name ).condition()

                   # There are many conditions one may apply to an Key( indexed_column_name ), but it is less than what is 
                   # available for Attr( column_name ). A full list of conditions that can act on Key() can be found in 
                   # Reference 6.

                   # For the current query, because we want to index over where 'topic' is equal to /apollo/canbus/chassis, the
                   # KeyConditionExpression checks exactly that.

                   # (Reference 6)

                   #-----------------------------------------------

                   ExpressionAttributeNames = {
                       
                                               '#time' : 'time'
                       
                                              },   
                   
                   # !!! ^^^ As mentioned in the description for ProjectionExpression, this parameter is where aliases for 
                   # columns that are reserved words in DynamoDB or have special characters that cause them to be 
                   # misinterpreted need to be defined in order to be used in expressions. (a dict)

                   # This is done by creating a dictionary where the keys are the aliases to be used in expressions (the
                   # aliases need to start with a #) and the values are the original columns that have issues.

                   # (It can alse be used to assign aliases to columns that have no issues, but are just cumbersome to
                   # write and you want to use them multiple times in expressions)

                   #------------------------------------------------

                   # ExpressionAttributeValues = 
    
                   # !!! ^^^ This parameter serves a very similar purpose to ExpressionAttributeNames,
                   # although instead of being used to assign aliases to columns, it is used
                   # to assign aliases to values, such as those in the table, that you want to
                   # use/check for in expressions. This may be necessary because of reserved words
                   # or special characters, or simply for convenience. (a dict)

                   # I cannot seem to get any examples of this working, so I am unsure how to use it
                   # right now
                  
                  )

# %%
# Because the previous cell has a lot of comments, let us summarize the goal of our query and write the query without the comments.

# We want to find the values for the 'time' and 'throttlePercentage' columns for rows containing the 'groupMetadataID' 
# column value 1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd by indexing over where the 'topic' column value is equal to 
# /apollo/canbus/chassis.

query_input = dict(
    
                   IndexName = 'topic-index',
    
                   Limit = 2000,

                   ProjectionExpression = '#time, throttlePercentage',
    
                   FilterExpression = Attr( 'groupMetadataID' ).eq( '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd' ),

                   KeyConditionExpression = Key( 'topic' ).eq( '/apollo/canbus/chassis' ),

                   ExpressionAttributeNames = {
                       
                                               '#time' : 'time'
                       
                                              },
    
                  )

# %%
# Putting this dictionary of query parameters into a 'query' method for the table 'adspp_table'

query_output = adspp_table.query( **query_input )

# %%
# We receive 2 rows out of 1584 rows queried that have '/apollo/canbus/chassis' as a topic
# and have their 'groupMetadataID' equal to '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd'

# It is worth noting that the 'LastEvaluatedKey' key is present in the output, indicating that the query has not
# iterated through the whole 'adspp_table'. We must keep querying the table with the same query parameters,
# except with the 'ExclusiveStartKey' equal to the 'LastEvaluatedKey' key, until the 'LastEvaluatedKey' eventually
# disappears from the output. Only then will our query be truly finished.

print( query_output[ 'Items' ], '\n' )

print( query_output[ 'ScannedCount' ], '\n' )

print( query_output.keys() )
# Out:
# [{'throttlePercentage': Decimal('8.7'), 'time': Decimal('1701972622544006277')}, {'throttlePercentage': Decimal('26.6'), 'time': Decimal('1701972567168325460')}]
#
# 1584
#
# dict_keys(['Items', 'Count', 'ScannedCount', 'LastEvaluatedKey', 'ResponseMetadata'])

# %%
# But first, let us save our results so far in a Pandas dataframe

query_output_df = pd.DataFrame.from_dict( pd.json_normalize( query_output[ 'Items' ] ), orient = 'columns' )

# %%
# Let's take a quick look at it

query_output_df
# Out:
#   throttlePercentage                 time
# 0                8.7  1701972622544006277
# 1               26.6  1701972567168325460

# %%
# Okay, now let's query the rest of the table, appending the results of our queries to the Pandas dataframe
# we just made as we loop through the table. (Actually, we won't loop through the whole table, it will take
# a long time, let's just do it 50 times for demonstration purposes)

i = 0 # Initializes a counting variable to check if the while loop has looped 50 times

while ( 'LastEvaluatedKey' in query_output.keys() ) and ( i < 50 ):

    # ^^^ A while loop that will continue looping as long as the 'LastEvaluatedKey' key still exists in
    # the query outputs and the counting variable is less than 50

    query_input[ 'ExclusiveStartKey' ] = query_output[ 'LastEvaluatedKey' ]

    # ^^^ Adds/updates a key in the query input parameters we defined earlier to tell a new query to
    # start at the item the previous query stopped at.

    query_output = adspp_table.query( **query_input )

    # ^^^ Runs the new query

    temp_df = pd.DataFrame.from_dict( pd.json_normalize( query_output[ 'Items' ] ), orient = 'columns' )

    # ^^^ Saves the new query results in a temporary dataframe

    query_output_df = pd.concat( [ query_output_df, temp_df ] )

    # ^^^ Appends the temporary dataframe to the 'query_output_df' defined earlier

    i = i + 1

    # Updates the counting variable

# %%
# Let's take a quick look at the dataframe again to see how many items we gained

query_output_df
# Out:
#   throttlePercentage                 time
# 0                8.7  1701972622544006277
# 1               26.6  1701972567168325460
# 0               10.9  1701972615505001146
# 0                4.5  1701972663564752123
# 0                9.3  1701972481598843155
# 1               31.9  1701972635842446038
# 0               16.8  1701972671647598777
# 1               37.9  1701972461119846140
# 2               12.9  1701972610729504880
# 0               13.8  1701972554034052416
# 0               17.2  1701972535424160483
# 1                8.3  1701972481571091461
# 2               16.2  1701972468136479054
# 0               13.1  1701972544894083626
# 0               17.8  1701972599148322372
# 1               24.7  1701972593866480919
# 0                  0  1701972658647039897
# 1                7.6  1701972623271171412
# 2               23.1  1701972641418945770
# 0               21.6  1701972568852187444
# 0                  0  1701972656203264850
# 1               79.9  1701972521696699367
# 0               18.2  1701972683526605820
# 1               16.3  1701972576506389864
# 2                7.1  1701972474311722077
# 0               31.6  1701972633004159078
# 0                7.1  1701972828531317713
# 1               14.9  1701972589251368013
# 0                6.4  1701972843479059147
# 1               14.5  1701972665115689325
# 0               11.2  1701972554565520893
# 0                 28  1701972566113638853
# 1                3.5  1701972500410245330
# 0               13.5  1701972672573268151
# 1               18.6  1701972648249573322
# 0               20.7  1701972548722780989
# 0               25.4  1701972564598483756
# 0               13.5  1701972589608207956
# 0               32.1  1701972462328083520

# %%
# Quite a few!

# If you wish to save the dataframe, you can use the .to_csv() method from Pandas
