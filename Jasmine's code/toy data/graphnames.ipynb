# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chassis_df = pd.read_csv( '/home/jle_linux/Desktop/TDMprivate/data/06cbdbc0-db4d-11ee-a158-97f8443fd730/' +
                               '_apollo_canbus_chassis/06cbdbc0-db4d-11ee-a158-97f8443fd730_apollo_canbus_chassis.csv' )

best_pose_df = pd.read_csv( '/home/jle_linux/Desktop/TDMprivate/data/06cbdbc0-db4d-11ee-a158-97f8443fd730/' +
                                 '_apollo_sensor_gnss_best_pose/' +
                                 '06cbdbc0-db4d-11ee-a158-97f8443fd730_apollo_sensor_gnss_best_pose.csv' )

# %%
chassis_df.head()
# Out:
#    brakePercentage                       groupMetadataID      drivingMode  \
# 0              0.0  06cbdbc0-db4d-11ee-a158-97f8443fd730  COMPLETE_MANUAL
# 1              0.0  06cbdbc0-db4d-11ee-a158-97f8443fd730  COMPLETE_MANUAL
# 2              0.0  06cbdbc0-db4d-11ee-a158-97f8443fd730  COMPLETE_MANUAL
# 3              0.0  06cbdbc0-db4d-11ee-a158-97f8443fd730  COMPLETE_MANUAL
# 4              0.0  06cbdbc0-db4d-11ee-a158-97f8443fd730  COMPLETE_MANUAL
#
#    speedMps                 time  throttlePercentage  steeringPercentage  \
# 0       0.0  1693494301113165469                 0.0          -34.701275
# 1       0.0  1693494301145044093                 0.0          -34.701275
# 2       0.0  1693494301187896638                 0.0          -34.701275
# 3       0.0  1693494301211437749                 0.0          -34.701275
# 4       0.0  1693494301254799428                 0.0          -34.701275
#
#   signal.turnSignal
# 0         TURN_NONE
# 1         TURN_NONE
# ...

# %%
best_pose_df.head()
# Out:
#     heightMsl                       groupMetadataID  latitudeStdDev  \
# 0  202.979063  06cbdbc0-db4d-11ee-a158-97f8443fd730        0.010338
# 1  202.976077  06cbdbc0-db4d-11ee-a158-97f8443fd730        0.010329
# 2  202.976105  06cbdbc0-db4d-11ee-a158-97f8443fd730        0.010346
# 3  202.978510  06cbdbc0-db4d-11ee-a158-97f8443fd730        0.010317
# 4  202.979463  06cbdbc0-db4d-11ee-a158-97f8443fd730        0.010343
#
#    longitude     solType  extendedSolutionStatus                 time  \
# 0 -82.127898  NARROW_INT                      33  1693494302079024174
# 1 -82.127898  NARROW_INT                      33  1693494303047747084
# 2 -82.127898  NARROW_INT                      33  1693494304060687314
# 3 -82.127898  NARROW_INT                      33  1693494305053737259
# 4 -82.127898  NARROW_INT                      33  1693494306051479383
#
#    heightStdDev     solStatus   latitude  longitudeStdDev  numSatsInSolution
# ...

# %%
plt.figure(figsize=(10,5), dpi = 200)
sns.scatterplot(x = 'latitude', y = 'longitude', data = best_pose_df, hue = 'numSatsInSolution', palette = 'Dark2')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 g = sns.PairGrid(iris)
#       2 g.map_diag(sns.histplot)
#       3 g.map_offdiag(sns.scatterplot)
#
# NameError: name 'iris' is not defined
